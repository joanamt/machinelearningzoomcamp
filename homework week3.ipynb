# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('hwdata.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_import=df[['neighbourhood_group','room_type','latitude','longitude','minimum_nights','price','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']]

# %%
df_import.head()
# Out:
#   neighbourhood_group        room_type  latitude  longitude  minimum_nights  \
# 0            Brooklyn     Private room  40.64749  -73.97237               1
# 1           Manhattan  Entire home/apt  40.75362  -73.98377               1
# 2           Manhattan     Private room  40.80902  -73.94190               3
# 3            Brooklyn  Entire home/apt  40.68514  -73.95976               1
# 4           Manhattan  Entire home/apt  40.79851  -73.94399              10
#
#    price  number_of_reviews  reviews_per_month  \
# 0    149                  9               0.21
# 1    225                 45               0.38
# 2    150                  0                NaN
# 3     89                270               4.64
# 4     80                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
df_import.isnull().sum()
# Out:
# neighbourhood_group                   0
# room_type                             0
# latitude                              0
# longitude                             0
# minimum_nights                        0
# price                                 0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df_import.reviews_per_month=df_import.reviews_per_month.fillna(0)
# Out:
# C:\Users\jotei\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_import.isnull().sum()
# Out:
# neighbourhood_group               0
# room_type                         0
# latitude                          0
# longitude                         0
# minimum_nights                    0
# price                             0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# Question 1

# %%
df_import.neighbourhood_group.value_counts() #manhattan
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# Split the data

# %%
from sklearn.model_selection import train_test_split

# %%
df_fulltrain,df_test=train_test_split(df_import,test_size=0.2,random_state=42)

# %%
df_train,df_val=train_test_split(df_fulltrain,test_size=0.25,random_state=42)

# %%
df_train.reset_index(drop=True)
df_test.reset_index(drop=True)
df_val.reset_index(drop=True)
# Out:
#      neighbourhood_group        room_type  latitude  longitude  \
# 0               Brooklyn     Private room  40.70239  -73.92931
# 1               Brooklyn  Entire home/apt  40.68498  -73.96618
# 2               Brooklyn  Entire home/apt  40.66911  -73.94824
# 3              Manhattan     Private room  40.79767  -73.96114
# 4              Manhattan  Entire home/apt  40.76075  -73.99893
# 5               Brooklyn  Entire home/apt  40.71120  -73.96566
# 6              Manhattan  Entire home/apt  40.73243  -74.00932
# 7              Manhattan  Entire home/apt  40.80630  -73.96268
# 8              Manhattan      Shared room  40.77169  -73.99117
# 9              Manhattan  Entire home/apt  40.80861  -73.94574
# 10             Manhattan  Entire home/apt  40.80549  -73.96393
# 11              Brooklyn     Private room  40.61964  -74.02518
# 12              Brooklyn  Entire home/apt  40.62795  -73.96281
# 13             Manhattan  Entire home/apt  40.77822  -73.98016
# ...

# %%
y_train=df_train.price.values
y_test=df_test.price.values
y_val=df_val.price.values
y_train
# Out:
# array([ 99,  57,  70, ..., 299,  65,  92], dtype=int64)

# %%
del df_train['price']
del df_test['price']
del df_val['price']

# %% [markdown]
# Question 2

# %%
df_train.dtypes
# Out:
# neighbourhood_group                object
# room_type                          object
# latitude                          float64
# longitude                         float64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']

# %%
df_train[numerical].corrwith(df_train.latitude )
# Out:
# latitude                          1.000000
# longitude                         0.080301
# minimum_nights                    0.027441
# number_of_reviews                -0.006246
# reviews_per_month                -0.007159
# calculated_host_listings_count    0.019375
# availability_365                 -0.005891
# dtype: float64

# %%
print(df_train[numerical].corrwith(df_train.latitude))
print()
print(df_train[numerical].corrwith(df_train.longitude))
print()
print(df_train[numerical].corrwith(df_train.minimum_nights))
print()
print(df_train[numerical].corrwith(df_train.number_of_reviews))
print()
print(df_train[numerical].corrwith(df_train.reviews_per_month))
print()
print(df_train[numerical].corrwith(df_train.calculated_host_listings_count))
print()
print(df_train[numerical].corrwith(df_train.availability_365))
# Out:
# latitude                          1.000000
# longitude                         0.080301
# minimum_nights                    0.027441
# number_of_reviews                -0.006246
# reviews_per_month                -0.007159
# calculated_host_listings_count    0.019375
# availability_365                 -0.005891
# dtype: float64
#
# latitude                          0.080301
# longitude                         1.000000
# minimum_nights                   -0.060660
# number_of_reviews                 0.055084
# reviews_per_month                 0.134642
# calculated_host_listings_count   -0.117041
# availability_365                  0.083666
# dtype: float64
#
# latitude                          0.027441
# longitude                        -0.060660
# minimum_nights                    1.000000
# number_of_reviews                -0.076020
# reviews_per_month                -0.120703
# calculated_host_listings_count    0.118647
# availability_365                  0.138901
# dtype: float64
# ...

# %% [markdown]
# Make price binary

# %%
above_average=np.zeros(len(y_train))
for i in range (len(y_train)):
    if y_train[i]>=152:
        above_average[i]=1
above_average
# Out:
# array([0., 0., 0., ..., 1., 0., 0.])

# %% [markdown]
# Question 3

# %%
from sklearn.metrics import mutual_info_score

# %%
def mutual_info_price_score(series):
    return mutual_info_score(series,above_average)
mi=df_train[categorical].apply(mutual_info_price_score)
mi
# Out:
# neighbourhood_group    0.046506
# room_type              0.143226
# dtype: float64

# %% [markdown]
# Question 4

# %%
#one hot enconding
from sklearn.feature_extraction import DictVectorizer
dicts=df_train[categorical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(dicts)
dv.transform(dicts)
dv.get_feature_names()
# Out:
# ['neighbourhood_group=Bronx',
#  'neighbourhood_group=Brooklyn',
#  'neighbourhood_group=Manhattan',
#  'neighbourhood_group=Queens',
#  'neighbourhood_group=Staten Island',
#  'room_type=Entire home/apt',
#  'room_type=Private room',
#  'room_type=Shared room']

# %%
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()
# Out:
# ['availability_365',
#  'calculated_host_listings_count',
#  'latitude',
#  'longitude',
#  'minimum_nights',
#  'neighbourhood_group=Bronx',
#  'neighbourhood_group=Brooklyn',
#  'neighbourhood_group=Manhattan',
#  'neighbourhood_group=Queens',
#  'neighbourhood_group=Staten Island',
#  'number_of_reviews',
#  'reviews_per_month',
#  'room_type=Entire home/apt',
#  'room_type=Private room',
#  'room_type=Shared room']

# %%
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

# %%
test_dicts=df_test[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(test_dicts)
X_test=dv.transform(test_dicts)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='lbfgs', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
w=model.coef_[0].round(3)
w0=model.intercept_[0]

# %%
y_pred=model.predict_proba(X_val)[:,1]
# Out:
# C:\Users\jotei\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)

# %%
y_pred
# Out:
# array([0.00012952, 0.00040934, 0.00033896, ..., 0.00015191, 0.00011644,
#        0.00021736])

# %%
above_average=np.zeros(len(y_val))
for i in range (len(y_val)):
    if y_val[i]>=152:
        above_average[i]=1
above_average
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
abovepred=(y_pred>=0.5)

# %%
abovepred.astype(int)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
(above_average==abovepred.astype(int)).mean()
# Out:
# 0.6934246855506698

# %% [markdown]
# Question 5

# %%
original_acc=0.6934246855506698

# %%
#model without neighbourhood_group

# %%
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['room_type']

# %%
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)
model.fit(X_train,y_train)
y_pred=model.predict_proba(X_val)[:,1]
above_average=np.zeros(len(y_val))
abovepred=(y_pred>=0.5)
for i in range (len(y_val)):
    if y_val[i]>=152:
        above_average[i]=1
above_average
new_acc=(above_average==abovepred.astype(int)).mean()
print(original_acc-new_acc)
# Out:
# 0.0
# C:\Users\jotei\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)

# %%
# model without room_type
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)
model.fit(X_train,y_train)
y_pred=model.predict_proba(X_val)[:,1]
above_average=np.zeros(len(y_val))
abovepred=(y_pred>=0.5)
for i in range (len(y_val)):
    if y_val[i]>=152:
        above_average[i]=1
above_average
new_acc=(above_average==abovepred.astype(int)).mean()
print(original_acc-new_acc)
# Out:
# 0.0
# C:\Users\jotei\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)

# %%
#model without number of reviews
numerical=['latitude','longitude','minimum_nights','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)
model.fit(X_train,y_train)
y_pred=model.predict_proba(X_val)[:,1]
above_average=np.zeros(len(y_val))
abovepred=(y_pred>=0.5)
for i in range (len(y_val)):
    if y_val[i]>=152:
        above_average[i]=1
above_average
new_acc=(above_average==abovepred.astype(int)).mean()
print(original_acc-new_acc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-98f73b94771f> in <module>()
#      15 from sklearn.linear_model import LogisticRegression
#      16 model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)
# ---> 17 model.fit(X_train,y_train)
#      18 y_pred=model.predict_proba(X_val)[:,1]
#      19 above_average=np.zeros(len(y_val))
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1289                       max_squared_sum=max_squared_sum,
#    1290                       sample_weight=sample_weight)
# -> 1291             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1292
#    1293         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
# ...

# %%
#model without reviews per month
numerical=['latitude','longitude','minimum_nights','number_of_reviews','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)
model.fit(X_train,y_train)
y_pred=model.predict_proba(X_val)[:,1]
above_average=np.zeros(len(y_val))
abovepred=(y_pred>=0.5)
for i in range (len(y_val)):
    if y_val[i]>=152:
        above_average[i]=1
above_average
new_acc=(above_average==abovepred.astype(int)).mean()
print(original_acc-new_acc)

# %% [markdown]
# Question 6

# %%
priceslog=np.log1p(df.price.values)

# %%
from sklearn.linear_model import Ridge

# %%
#alpha 1
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

model = Ridge(alpha=1.0)
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

y_pred=model.predict(X_val)
y_pred
# Out:
# array([ 46.15171352, 244.28054473, 176.14668241, ..., 135.24308666,
#         65.98427709, 203.78421508])

# %%
def rmse(y,y_pred):
    error=y-y_pred
    se=error**2
    mse=se.mean()
    return np.sqrt(mse)
rmse(y_val,y_pred)
# Out:
# 211.9030691187127

# %%
#alpha 0
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

model = Ridge(alpha=0)
model.fit(X_train,y_train)
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

y_pred=model.predict(X_val)

print(rmse(y_val,y_pred))
# Out:
# 211.9022956825595

# %%
#alpha 0.01
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

model = Ridge(alpha=0.01)
model.fit(X_train,y_train)
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

y_pred=model.predict(X_val)

print(rmse(y_val,y_pred))
# Out:
# 211.9027328944188

# %%
#alpha 0.1
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

model = Ridge(alpha=0.1)
model.fit(X_train,y_train)
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

y_pred=model.predict(X_val)

print(rmse(y_val,y_pred))
# Out:
# 211.90268860605966

# %%
#alpha 10
numerical=['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
categorical=['neighbourhood_group','room_type']
train_dicts=df_train[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train=dv.transform(train_dicts)
dv.get_feature_names()

model = Ridge(alpha=10)
model.fit(X_train,y_train)
val_dicts=df_val[categorical + numerical].to_dict(orient='records')
dv=DictVectorizer(sparse=False)
dv.fit(val_dicts)
X_val=dv.transform(val_dicts)

y_pred=model.predict(X_val)

print(rmse(y_val,y_pred))
# Out:
# 211.94999657439922
